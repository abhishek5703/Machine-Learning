# %% [markdown]
# ## Data Visualization with Seaborn

# %% [markdown]
# Seaborn is a Python visualization library based on Matplotlib that provides a high-level interface for drawing attractive and informative statistical graphics . Seaborn helps in creating complex visualization with just a few lines of code

# %% [markdown]
# NOTE:- In terms of plotting and visualization it is much better as compared to the matplotlib library

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
tips  = sns.load_dataset('tips') # tips is an example inbuilt dataset 
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# cerate a scatter plot
import matplotlib.pyplot as plt

sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.title('Scatter Plot of total_bill vs the tip')
plt.show()

# %%
# line plot
sns.lineplot(x='size',y='total_bill',data=tips)
plt.title('Line Plot of Total bills by size')
# Out:
# Text(0.5, 1.0, 'Line Plot of Total bills by size')

# %%
# Categorical Plots (Bar Plot)
sns.barplot(x='day',y='total_bill',data=tips)
plt.title('Bar Plot of the total bill by day')
# Out:
# Text(0.5, 1.0, 'Bar Plot of the total bill by day')

# %%
# Box Plot
sns.boxplot(x='day',y='total_bill',data=tips)
plt.title('Box Plot of day and the total bill')
# it shows the percentile like the 20 percentile , 30 percentile etc
# Out:
# Text(0.5, 1.0, 'Box Plot of day and the total bill')

# %%
# Violin Plot
sns.violinplot(x='day',y='total_bill',data=tips)
plt.title('Violin Plot b/w day and the total_bill')
# this plot will shows the distribution of the data A violin plot shows the distribution of data and combines features of a box plot and a histogram.It helps you see: Median and the Spread of data
# Out:
# Text(0.5, 1.0, 'Violin Plot b/w day and the total_bill')

# %%
## Histograms
sns.histplot(tips['total_bill'],bins=10,kde=True)
# this will be count the range , like how many bills are there between 0 to 10
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(tips['total_bill'],bins=10,kde=False)
# kde means Kernel Density Estimate. It adds a smooth curve showing the probability density of the data.
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
## KDE plot
sns.kdeplot(tips['total_bill'],shade=True)
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_12456\1948633153.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips['total_bill'],shade=True)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# Pairplot  :-A pairplot in Seaborn is used to visualize relationships between multiple numerical variables in a dataset.
# It automatically creates scatter plots for every pair of variables and histograms for each individual variable.

sns.pairplot(tips)
# it is not for the categorical data

# %%
# Heatmap :- It shows the correlation b/w any two numericals values of the data
corr = tips[['total_bill','tip','size']].corr() # it will find the correlation b/w these 3 different variables 
corr
# You can see in the O/P that if total_bill is increased by 1 unit then tip will be increased by 0.68 unit and the size will be increased by the factor of 0.6 unit and this relation is shown by the heat map by using some colors
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
# annot=True :- This shows the number in the cell
# cmap='coolwarm' :- Red → higher values and Blue → lower values
# Out:
# <Axes: >

# %%
import pandas as pd
sales_df = pd.read_csv('sales1_data.csv')
sales_df.head()
# Out:
#          Date Product Category  Total Revenue Region
# 0  2023-01-01      Electronics           1200  North
# 1  2023-01-02         Clothing            800  South
# 2  2023-01-03        Furniture           1500   West
# 3  2023-01-04        Groceries            600   East
# 4  2023-01-05           Sports            950  North

# %%
## Plot total sales by product
plt.figure(figsize=(10,6))
sns.barplot(x='Product Category',y='Total Revenue',data=sales_df,estimator=sum)
plt.title('Total Sales by Product')
plt.xlabel('Product')
plt.ylabel('Total Sales')
plt.show()

# %%
## Plot total sales by region
plt.figure(figsize=(10,6))
sns.barplot(x='Region',y='Total Revenue',data=sales_df,estimator=sum)
plt.title('Total Sales by Product')
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.show()
