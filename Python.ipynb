# %% [markdown]
# ## Introduction to Python

# %% [markdown]
# It is a programming lanugage used in AI/ML also

# %%
## python is case sensitive
name = "Abhishek"
Name = "kumar"  ## both variables are different 
print(name)
print(Name)
# Out:
# Abhishek
# kumar

# %% [markdown]
# NOTE :- Intendation is python is just like a {} in other languages to define a block of code and it defines the structure and the hierarchy of the blocks of the code

# %%
## Line Contiuation
total = 1+2+3+\
4+5
print(total)
# Out:
# 15

# %%
## Multiple statement in a single line
x=10;y= 5;z=x+y

# %%
## In python the data type of the variable decides on the run time so you can change it to the run time and that's why it is a dynamically typed variables 
variable = 10 
print(type(variable))
variable = "kk"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
result = "hello" + 5    # type casting is imp
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 result = "hello" + 5
#       2 print(result)
#
# TypeError: can only concatenate str (not "int") to str

# %%
result = "hello" + str(5)
print(result)
# Out:
# hello5

# %% [markdown]
# ## Module and Packages

# %%
import math   # importing the package which has so many inbuilt functions which you can use 
math.sqrt(16) # using the package
# Out:
# 4.0

# %%
from math import sqrt , pi
print(sqrt(16)) #now i can use it without writing math again & again since i have import it 
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])
